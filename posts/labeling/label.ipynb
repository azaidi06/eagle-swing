# %% [markdown]
# ---
# title: "Auto Label"
# author: "Ali Zaidi"
# date: "2025-11-14"
# categories: [Data Engineering]
# description: "Now that we have our clipped video files, lets label them at full precision"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %%
from fastai.vision.all import *

# %%
files = get_files('.')
file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 files = get_files('.')
# ----> 2 file
#
# NameError: name 'file' is not defined

# %% [markdown]
# Take the back half of auto-clipper and bring it here
